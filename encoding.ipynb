# %% [markdown]
# # Ordinal Encoder

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\dell\Downloads\Cases_Data_B._Cases_Dataset_(CSV).csv")

# %%
df
# Out:
#                              Borough  Borough Code  \
# 0             Anchorage Municipality            20
# 1            Kenai Peninsula Borough           122
# 2       Fairbanks North Star Borough            90
# 3       Fairbanks North Star Borough            90
# 4          Ketchikan Gateway Borough           130
# ...                              ...           ...
# 294786       Kenai Peninsula Borough           122
# 294787        Anchorage Municipality            20
# 294788       Kenai Peninsula Borough           122
# 294789        Anchorage Municipality            20
# 294790        Anchorage Municipality            20
#
#                                       BHR  BHR Code Report Date  Onset Date  \
# 0                  Anchorage Municipality         1  03/18/2020  03/07/2020
# 1                 Kenai Peninsula Borough         4  03/18/2020  03/15/2020
# 2            Fairbanks North Star Borough         2  03/16/2020  03/12/2020
# ...

# %%
temp1=df.iloc[:,2]

# %% [markdown]
# temp1

# %%
temp1
# Out:
# 0                    Anchorage Municipality
# 1                   Kenai Peninsula Borough
# 2              Fairbanks North Star Borough
# 3              Fairbanks North Star Borough
# 4         Other Southeast Region - Southern
#                         ...
# 294786              Kenai Peninsula Borough
# 294787               Anchorage Municipality
# 294788              Kenai Peninsula Borough
# 294789               Anchorage Municipality
# 294790               Anchorage Municipality
# Name: BHR, Length: 294791, dtype: object

# %%
unique1=temp1.unique()

# %%
temp=df[['BHR']]

# %%
unique1
# Out:
# array(['Anchorage Municipality', 'Kenai Peninsula Borough',
#        'Fairbanks North Star Borough',
#        'Other Southeast Region - Southern',
#        'Other Southeast Region - Northern', 'Matanuska-Susitna Borough',
#        'Juneau City and Borough', 'Other Interior Region',
#        'Y-K Delta Region', 'Northwest Region', 'Southwest Region',
#        'Unknown'], dtype=object)

# %% [markdown]
# # Label Encoder

# %%
from sklearn.preprocessing import OrdinalEncoder
import numpy as np
import pandas as pd

# %%
temp=df[['BHR']]

# %%
obj=OrdinalEncoder(categories=[['Anchorage Municipality', 'Kenai Peninsula Borough',
       'Fairbanks North Star Borough',
       'Other Southeast Region - Southern',
       'Other Southeast Region - Northern', 'Matanuska-Susitna Borough',
       'Juneau City and Borough', 'Other Interior Region',
       'Y-K Delta Region', 'Northwest Region', 'Southwest Region',
       'Unknown']])

# %%
fit1=obj.fit(temp)

# %%
T=obj.transform(temp)

# %%
new_df1=pd.concat([temp,pd.DataFrame(T,columns=['BHR1'])],axis=1)

# %%
new_df1
# Out:
#                                       BHR  BHR1
# 0                  Anchorage Municipality   0.0
# 1                 Kenai Peninsula Borough   1.0
# 2            Fairbanks North Star Borough   2.0
# 3            Fairbanks North Star Borough   2.0
# 4       Other Southeast Region - Southern   3.0
# ...                                   ...   ...
# 294786            Kenai Peninsula Borough   1.0
# 294787             Anchorage Municipality   0.0
# 294788            Kenai Peninsula Borough   1.0
# 294789             Anchorage Municipality   0.0
# 294790             Anchorage Municipality   0.0
#
# [294791 rows x 2 columns]

# %%
T
# Out:
# array([[0.],
#        [1.],
#        [2.],
#        ...,
#        [1.],
#        [0.],
#        [0.]])

# %%
temp.shape
# Out:
# (294791, 1)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
obj1 = LabelEncoder()

# %%
obj1.fit(temp)
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LabelEncoder()

# %%
 encode=obj1.transform(temp)
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
new_df=pd.concat([new_df1,pd.DataFrame(encode,columns=['BHR2'])],axis=1)

# %%
new_df
# Out:
#                                       BHR  BHR1  BHR2
# 0                  Anchorage Municipality   0.0     0
# 1                 Kenai Peninsula Borough   1.0     3
# 2            Fairbanks North Star Borough   2.0     1
# 3            Fairbanks North Star Borough   2.0     1
# 4       Other Southeast Region - Southern   3.0     8
# ...                                   ...   ...   ...
# 294786            Kenai Peninsula Borough   1.0     3
# 294787             Anchorage Municipality   0.0     0
# 294788            Kenai Peninsula Borough   1.0     3
# 294789             Anchorage Municipality   0.0     0
# 294790             Anchorage Municipality   0.0     0
#
# [294791 rows x 3 columns]

# %% [markdown]
# # Nomial Encoder
#    Dummy
#    One Hot Encoding

# %%
pd.get_dummies(df['BHR'])
# Out:
#         Anchorage Municipality  Fairbanks North Star Borough  \
# 0                            1                             0
# 1                            0                             0
# 2                            0                             1
# 3                            0                             1
# 4                            0                             0
# ...                        ...                           ...
# 294786                       0                             0
# 294787                       1                             0
# 294788                       0                             0
# 294789                       1                             0
# 294790                       1                             0
#
#         Juneau City and Borough  Kenai Peninsula Borough  \
# 0                             0                        0
# 1                             0                        1
# 2                             0                        0
# ...

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
df
# Out:
#                              Borough  Borough Code  \
# 0             Anchorage Municipality            20
# 1            Kenai Peninsula Borough           122
# 2       Fairbanks North Star Borough            90
# 3       Fairbanks North Star Borough            90
# 4          Ketchikan Gateway Borough           130
# ...                              ...           ...
# 294786       Kenai Peninsula Borough           122
# 294787        Anchorage Municipality            20
# 294788       Kenai Peninsula Borough           122
# 294789        Anchorage Municipality            20
# 294790        Anchorage Municipality            20
#
#                                       BHR  BHR Code Report Date  Onset Date  \
# 0                  Anchorage Municipality         1  03/18/2020  03/07/2020
# 1                 Kenai Peninsula Borough         4  03/18/2020  03/15/2020
# 2            Fairbanks North Star Borough         2  03/16/2020  03/12/2020
# ...

# %%
obj3=OneHotEncoder(drop='first',sparse=True)

# %%
obj3.fit(df[['BHR']])
# Out:
# OneHotEncoder(drop='first')

# %%
m=obj3.transform(df[['BHR']]).toarray().shape

# %%
m
# Out:
# (294791, 11)

# %%
df1=pd.read_csv(r"C:\Users\dell\Downloads\house.csv.csv")

# %%
df1
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
p=df.dropna()

# %%
p
# Out:
#                              Borough  Borough Code  \
# 0             Anchorage Municipality            20
# 1            Kenai Peninsula Borough           122
# 2       Fairbanks North Star Borough            90
# 3       Fairbanks North Star Borough            90
# 4          Ketchikan Gateway Borough           130
# ...                              ...           ...
# 294786       Kenai Peninsula Borough           122
# 294787        Anchorage Municipality            20
# 294788       Kenai Peninsula Borough           122
# 294789        Anchorage Municipality            20
# 294790        Anchorage Municipality            20
#
#                                       BHR  BHR Code Report Date  Onset Date  \
# 0                  Anchorage Municipality         1  03/18/2020  03/07/2020
# 1                 Kenai Peninsula Borough         4  03/18/2020  03/15/2020
# 2            Fairbanks North Star Borough         2  03/16/2020  03/12/2020
# ...

# %%
temp=p['size']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'size'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
temp

# %%
temp.unique()

# %%
temp1=p[['size']]

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
enco=OrdinalEncoder(categories=[['2 BHK', '4 Bedroom', '3 BHK', '3 Bedroom', '1 RK', '4 BHK',
       '1 BHK', '5 BHK', '11 BHK', '5 Bedroom', '9 BHK', '2 Bedroom',
       '6 BHK', '7 BHK', '6 Bedroom']])

# %%
enco.fit(temp1)

# %%
enco.transform(temp1)

# %%
p1=pd.get_dummies(df['size'])

# %%
concate=pd.concat([temp1,p1],axis=1)

# %%
concate.to_string()

# %%
# !pip install imblearn

# %% [markdown]
# # upsampling/OverSampling

# %%
df
# Out:
#                              Borough  Borough Code  \
# 0             Anchorage Municipality            20
# 1            Kenai Peninsula Borough           122
# 2       Fairbanks North Star Borough            90
# 3       Fairbanks North Star Borough            90
# 4          Ketchikan Gateway Borough           130
# ...                              ...           ...
# 294786       Kenai Peninsula Borough           122
# 294787        Anchorage Municipality            20
# 294788       Kenai Peninsula Borough           122
# 294789        Anchorage Municipality            20
# 294790        Anchorage Municipality            20
#
#                                       BHR  BHR Code Report Date  Onset Date  \
# 0                  Anchorage Municipality         1  03/18/2020  03/07/2020
# 1                 Kenai Peninsula Borough         4  03/18/2020  03/15/2020
# 2            Fairbanks North Star Borough         2  03/16/2020  03/12/2020
# ...

# %%
X=df.drop(['Occurrence (Y/N)'],axis=1)

# %%
y=df['Occurrence (Y/N)']

# %%
y
# Out:
# 0         Y
# 1         Y
# 2         Y
# 3         Y
# 4         Y
#          ..
# 294786    Y
# 294787    Y
# 294788    Y
# 294789    Y
# 294790    Y
# Name: Occurrence (Y/N), Length: 294791, dtype: object

# %%
X
# Out:
#                              Borough  Borough Code  \
# 0             Anchorage Municipality            20
# 1            Kenai Peninsula Borough           122
# 2       Fairbanks North Star Borough            90
# 3       Fairbanks North Star Borough            90
# 4          Ketchikan Gateway Borough           130
# ...                              ...           ...
# 294786       Kenai Peninsula Borough           122
# 294787        Anchorage Municipality            20
# 294788       Kenai Peninsula Borough           122
# 294789        Anchorage Municipality            20
# 294790        Anchorage Municipality            20
#
#                                       BHR  BHR Code Report Date  Onset Date  \
# 0                  Anchorage Municipality         1  03/18/2020  03/07/2020
# 1                 Kenai Peninsula Borough         4  03/18/2020  03/15/2020
# 2            Fairbanks North Star Borough         2  03/16/2020  03/12/2020
# ...

# %%
df['Occurrence (Y/N)'].value_counts()
# Out:
# Y    293011
# N      1780
# Name: Occurrence (Y/N), dtype: int64

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
over=  RandomOverSampler(sampling_strategy=0.30)

# %%
X_new,y_new=over.fit_resample(X,y)

# %%
X_new
# Out:
#                              Borough  Borough Code  \
# 0             Anchorage Municipality            20
# 1            Kenai Peninsula Borough           122
# 2       Fairbanks North Star Borough            90
# 3       Fairbanks North Star Borough            90
# 4          Ketchikan Gateway Borough           130
# ...                              ...           ...
# 380909        Anchorage Municipality            20
# 380910  Fairbanks North Star Borough            90
# 380911            Petersburg Borough           195
# 380912     Matanuska-Susitna Borough           170
# 380913       Juneau City and Borough           110
#
#                                       BHR  BHR Code Report Date  Onset Date  \
# 0                  Anchorage Municipality         1  03/18/2020  03/07/2020
# 1                 Kenai Peninsula Borough         4  03/18/2020  03/15/2020
# 2            Fairbanks North Star Borough         2  03/16/2020  03/12/2020
# ...

# %%
y_new.value_counts()
# Out:
# Y    293011
# N     87903
# Name: Occurrence (Y/N), dtype: int64

# %%
(293011/100)*30
# Out:
# 87903.3

# %%
from imblearn.under_sampling import NearMiss

# %%
under=NearMiss(sampling_strategy=0.30)

# %%
X_new_under,y_mew_under=under.fit_resample(X,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6544\1099732873.py in <module>
# ----> 1 X_new_under,y_mew_under=under.fit_resample(X,y)
#
# ~\anaconda3\lib\site-packages\imblearn\base.py in fit_resample(self, X, y)
#     201         """
#     202         self._validate_params()
# --> 203         return super().fit_resample(X, y)
#     204
#     205     def _more_tags(self):
#
# ~\anaconda3\lib\site-packages\imblearn\base.py in fit_resample(self, X, y)
#      80         check_classification_targets(y)
#      81         arrays_transformer = ArraysTransformer(X, y)
# ---> 82         X, y, binarize_y = self._check_X_y(X, y)
#      83
#      84         self.sampling_strategy_ = check_sampling_strategy(
#
# ~\anaconda3\lib\site-packages\imblearn\base.py in _check_X_y(self, X, y, accept_sparse)
#     154             accept_sparse = ["csr", "csc"]
# ...
